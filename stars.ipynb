# %%
star = '*'
i = 0
while i < 5:
    i += 1
    print(star * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
star = '*'
i = 6
while i > 0:
    i -= 1
    print(star * i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
str = 'python'
x = 1
while x < len(str) + 1:
    print(str[:0 + x])
    x += 1
# Out:
# p
# py
# pyt
# pyth
# pytho
# python

# %%
str = 'python'
x = 0
while x < len(str):
    print(str[0:len(str) - x])
    x += 1
# Out:
# python
# pytho
# pyth
# pyt
# py
# p
